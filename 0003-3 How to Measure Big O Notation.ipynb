# %% [markdown]
# ![26.PNG](attachment:26.PNG)

# %% [markdown]
# ![27.PNG](attachment:27.PNG)

# %% [markdown]
# ### How to Measure Recursive Algorithm ?
# ![28.PNG](attachment:28.PNG)

# %% [markdown]
# ![30.PNG](attachment:30.PNG)

# %% [markdown]
# ### How to measure Recursive Algorithm that makes multiple calls ?
# ![32.PNG](attachment:32.PNG)

# %% [markdown]
# ### Recursive Algorithm
# ### Single call : $O(n)$
# ### Multiple calls : $O(Branches^{Depth})$

# %% [markdown]
# ### Quiz :
# ![33.PNG](attachment:33.PNG)

# %% [markdown]
# ![34.PNG](attachment:34.PNG)

# %% [markdown]
# ![35.PNG](attachment:35.PNG)

# %% [markdown]
# ![36.PNG](attachment:36.PNG)

# %% [markdown]
# ![37.PNG](attachment:37.PNG)
