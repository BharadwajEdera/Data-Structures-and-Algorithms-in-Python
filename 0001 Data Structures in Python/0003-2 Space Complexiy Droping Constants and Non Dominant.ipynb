# %% [markdown]
# # 01 Space Complexity
# ![20.PNG](attachment:20.PNG)

# %% [markdown]
# ![20.PNG](attachment:20.PNG)

# %% [markdown]
# ![21.PNG](attachment:21.PNG)

# %% [markdown]
# ![22.PNG](attachment:22.PNG)

# %% [markdown]
# # 02 Droping Constants and Non Dominant terms
# ![23.PNG](attachment:23.PNG)

# %% [markdown]
# ### Why do we drop constants and Non Determinant terms ?
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# # Add vs Multiply
# ![25.PNG](attachment:25.PNG)
