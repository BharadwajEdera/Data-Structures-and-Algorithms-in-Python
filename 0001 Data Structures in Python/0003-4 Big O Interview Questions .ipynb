# %% [markdown]
# ### Question 1
# ![38.PNG](attachment:38.PNG)
# ### Ans : Runtime : $O(N)$

# %% [markdown]
# ### Question 2 :
# > Outer Loop and Inner Loop has same Array
#
# > Runtime : $O(N^2)$
#
# ![39.PNG](attachment:39.PNG)
# ### Ans : Runtime : $O(N^2)$

# %% [markdown]
# ### Question 3 :
# ![40.PNG](attachment:40.PNG)
# ### Ans : Runtime : $O(N^2)$

# %% [markdown]
# ### Question 4 :
# > Outer Loop has Different Array "A"
#
# > Inner Loop has Different array "B"
#
# > Runtime : $O(ab)$
#
# ![41.PNG](attachment:41.PNG)
# ### Ans : Runtime : $O(ab)$

# %% [markdown]
# ### Question 5 :
# >Note ::: for i in range(Constant_Number) :: $O(1)$
#
# ![42.PNG](attachment:42.PNG)
# ### Ans : Runtime : $O(ab)$

# %% [markdown]
# ![43.PNG](attachment:43.PNG)

# %% [markdown]
# ### Question 6 :
# ![44.PNG](attachment:44.PNG)
# ### Ans : Runtime : $O(N)$

# %% [markdown]
# ### Question 7 :
# ![45.PNG](attachment:45.PNG)
# ### Ans : Runtime :

# %% [markdown]
# ### Question 8 :
# > Note : Single recursive call : $O(N)$
#
# ![46.PNG](attachment:46.PNG)
# ### Ans : Runtime : $O(N)$

# %% [markdown]
# ### Question 9 :
# > Note : Multiple recursive call :  $O(brances^{depth})$
#
# ![47.PNG](attachment:47.PNG)
# ### Ans : Runtime : $O(2^N)$

# %% [markdown]
# ### Question 10 :
# ![48.PNG](attachment:48.PNG)
# ### Ans : Runtime : $O(logN)$

# %% [markdown]
# ![49.PNG](attachment:49.PNG)

# %% [markdown]
# ![37.PNG](attachment:37.PNG)
