# %% [markdown]
# # 01 Arrays
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# # 02 Properties of Array
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # 03 Types of an Array
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# # 04 Arrays in Memory
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %% [markdown]
# # 05 Creating an Array
# ![9.PNG](attachment:9.PNG)

# %% [markdown]
# ![10.PNG](attachment:10.PNG)
#
# ### Array Time Complexity : $O(1)$
# >### Creating an Empty Array and Assigning Values to Array :Time Complexity : $O(N)$

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
print(arr1)
arr2 = array('d', [1,2.5,3.6])
print(arr2)
# Out:
# array('i', [1, 2, 3, 4, 55, 6])
# array('d', [1.0, 2.5, 3.6])

# %% [markdown]
# # 06 Insertion into an Array
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ### Inserting an Element When array is full
# ![13.PNG](attachment:13.PNG)

# %% [markdown]
# ### Inserting Element at the End

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
print(arr1)

arr1.insert(6,7)
print(arr1)
# Out:
# array('i', [1, 2, 3, 4, 55, 6])
# array('i', [1, 2, 3, 4, 55, 6, 7])

# %% [markdown]
# ### Inserting Element at The Begining

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
print(arr1)

arr1.insert(0,0)
print(arr1)
# Out:
# array('i', [1, 2, 3, 4, 55, 6])
# array('i', [0, 1, 2, 3, 4, 55, 6])

# %% [markdown]
# ### Inserting Elements in between

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
print(arr1)

arr1.insert(2,0)
print(arr1)
# Out:
# array('i', [1, 2, 3, 4, 55, 6])
# array('i', [1, 2, 0, 3, 4, 55, 6])

# %% [markdown]
# ### Insertion of an element into an Array at
# ### Begining :: Time Complexity :: $O(N)$
# ### End :: Time Complexity :: $O(1)$
# ### In Between :: Time Complexity :: $O(N)$
# ### Insertion into Full Array :: Time Complexity :: $O(N)$

# %% [markdown]
# # 07 Array Traversal
# ![14.PNG](attachment:14.PNG)

# %%
def traverseArray(array):
    for i in array:
        print(i)

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
traverseArray(arr1)
# Out:
# 1
# 2
# 3
# 4
# 55
# 6

# %% [markdown]
# ### Array Traversal
# ### Time Complexity :: $O(N)$
# ### Space Complexity :: $O(1)$
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# # 08 Access Array Element
# ![16.PNG](attachment:16.PNG)

# %% [markdown]
# ![17.PNG](attachment:17.PNG)

# %%
def accesElement(array , index):
    if index > len(array):
        print("Error : Index Out of range of Array")
    else:
        return array[index]

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
accesElement(arr1,2)
# Out:
# 3

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
accesElement(arr1,10)
# Out:
# Error : Index Out of range of Array

# %% [markdown]
# ### Access Element in array
# ### Time Complexity :: $O(1)$
# ### Space Complexity :: $O(1)$
# ![18.PNG](attachment:18.PNG)

# %% [markdown]
# # 09 Finding an Element in an Array
# ![21.PNG](attachment:21.PNG)

# %%
def SearchInArray(array , value):
    for i in array:
        if i == value:
            return array.index(value)
    return "The Element doesnt exists in an array"

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
SearchInArray(arr1,55)
# Out:
# 4

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
SearchInArray(arr1,60)
# Out:
# 'The Element doesnt exists in an array'

# %% [markdown]
# ### Finding an Element in array
# ### Time Complexity :: $O(N)$
# ### Space Complexity :: $O(1)$
# ![22.PNG](attachment:22.PNG)

# %% [markdown]
# # 10 Delete an Element from an array
# ![23.PNG](attachment:23.PNG)

# %% [markdown]
# ![24.PNG](attachment:24.PNG)

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
arr1.remove(3)
print(arr1)
# Out:
# array('i', [1, 2, 4, 55, 6])

# %%
from array import *
arr1 = array('i', [1,2,3,4,55,6])
arr1.remove(6)
print(arr1)
# Out:
# array('i', [1, 2, 3, 4, 55])

# %% [markdown]
# ### Deleting an Element in array
# ### Time Complexity :: $O(N)$
# ### Space Complexity :: $O(1)$
# ![25.PNG](attachment:25.PNG)

# %% [markdown]
# ![26.PNG](attachment:26.PNG)

# %% [markdown]
# ### Practise

# %%
from array import *

# %%
# 1. Create an array and traverse. 

my_array = array('i',[1,2,3,4,5])

for i in my_array:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# 2. Access individual elements through indexes
print("Step 2")
print(my_array[3])
# Out:
# Step 2
# 4

# %%
# 3. Append any value to the array using append() method

print("Step 3")
my_array.append(6)
print(my_array)
# Out:
# Step 3
# array('i', [1, 2, 3, 4, 5, 6])

# %%
# 4. Insert value in an array using insert() method
print("Step 4")
my_array.insert(3, 11)
print(my_array)
# Out:
# Step 4
# array('i', [1, 2, 3, 11, 4, 5, 6])

# %%
# 5. Extend python array using extend() method
print("Step 5")
my_array1 = array('i', [10,11,12])
my_array.extend(my_array1)
print(my_array)
# Out:
# Step 5
# array('i', [1, 2, 3, 11, 4, 5, 6, 10, 11, 12])

# %%
# 6. Add items from list into array using fromlist() method
print("Step 6")
tempList = [20,21,22]
my_array.fromlist(tempList)
print(my_array)
# Out:
# Step 6
# array('i', [1, 2, 3, 11, 4, 5, 6, 10, 11, 12, 20, 21, 22])

# %%
# 7. Remove any array element using remove() method
print("Step 7")
my_array.remove(11)
print(my_array)
# Out:
# Step 7
# array('i', [1, 2, 3, 4, 5, 6, 10, 11, 12, 20, 21, 22])

# %%
# 8. Remove last array element using pop() method
print("Step 8")
my_array.pop()
print(my_array)
# Out:
# Step 8
# array('i', [1, 2, 3, 4, 5, 6, 10, 11, 12, 20, 21])

# %%
# 9. Fetch any element through its index using index() method
print("Step 9")
print(my_array.index(21))
# Out:
# Step 9
# 10

# %%
# 10. Reverse a python array using reverse() method
print("Step 10")
my_array.reverse()
print(my_array)
# Out:
# Step 10
# array('i', [21, 20, 12, 11, 10, 6, 5, 4, 3, 2, 1])

# %%
# 11. Get array buffer information through buffer_info() method
print("Step 11")
print(my_array.buffer_info())
# Out:
# Step 11
# (2533903441176, 11)

# %%
# 12. Check for number of occurrences of an element using count() method
print("Step 12")
my_array.append(11)
print(my_array.count(11))
print(my_array)
# Out:
# Step 12
# 2
# array('i', [21, 20, 12, 11, 10, 6, 5, 4, 3, 2, 1, 11])

# %%
# 13. Convert array to string using tostring() method
print("Step 13")
strTemp = my_array.tostring()
print(strTemp)
ints = array('i')
ints.fromstring(strTemp)
print(ints)
# Out:
# Step 13
# b'\x15\x00\x00\x00\x14\x00\x00\x00\x0c\x00\x00\x00\x0b\x00\x00\x00\n\x00\x00\x00\x06\x00\x00\x00\x05\x00\x00\x00\x04\x00\x00\x00\x03\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x0b\x00\x00\x00'
# array('i', [21, 20, 12, 11, 10, 6, 5, 4, 3, 2, 1, 11])

# %%
# 14. Convert array to a python list with same elements using tolist() method
print("Step 14")
print(my_array.tolist())
# Out:
# Step 14
# [21, 20, 12, 11, 10, 6, 5, 4, 3, 2, 1, 11]

# %%
# 15. Append a string to char array using fromstring() method

# 16. Slice Elements from an array
print("Step 16")
print(my_array[2:6])
# Out:
# Step 16
# array('i', [12, 11, 10, 6])
