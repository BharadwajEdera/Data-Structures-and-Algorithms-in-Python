# %% [markdown]
# # Searching for a Node in Binary
# > ### For Searching we use Level Order Traversal
#
# > ### Because in Level order Traversal we use Queue
#
# > ### As We know Queue performs better than Stack
#
#
#
# ### Time Complexity : $O(N)$ , Beacause while Loop
# ### Space Complexity : $O(N)$ , Because Creating Queue and inserting elements
#
# ![28.PNG](attachment:28.PNG)

# %%
class Node:
    def __init__(self, value=None):
        self.value = value
        self.next = None
    
    def __str__(self):
        return str(self.value)

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def __iter__(self):
        curNode = self.head
        while curNode:
            yield curNode
            curNode = curNode.next

class Queue:
    def __init__(self):
        self.linkedList = LinkedList()
    
    def __str__(self):
        if self.linkedList.head == None:
            return "Queue is EMpty"
        else:
            values = [str(x) for x in self.linkedList]
            return ' '.join(values)
    
    def enqueue(self, value):
        newNode = Node(value)
        if self.linkedList.head == None:
            self.linkedList.head = newNode
            self.linkedList.tail = newNode
        else:
            self.linkedList.tail.next = newNode
            self.linkedList.tail = newNode
    
    def isEmpty(self):
        if self.linkedList.head == None:
            return True
        else:
            return False
    
    def dequeue(self):
        if self.isEmpty():
            return "There is not any node in the Queue"
        else:
            tempNode = self.linkedList.head
            if self.linkedList.head == self.linkedList.tail:
                self.linkedList.head = None
                self.linkedList.tail = None
            else:
                self.linkedList.head = self.linkedList.head.next
            return tempNode
    
    def peek(self):
        if self.isEmpty():
            return "There is not any node in the Queue"
        else:
            return self.linkedList.head
    
    def delete(self):
        self.linkedList.head = None
        self.linkedList.tail = None
        return "Queue Deleted"

# %%
class TreeNode:
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None

# %%
T = TreeNode("Drinks")
L_C = TreeNode("Hot")
R_C = TreeNode("Cold")

T.LeftChild = L_C
T.RightChild = R_C

L_C_L_C = TreeNode("Tea")
L_C_R_C = TreeNode("Coffee")

L_C.LeftChild = L_C_L_C
L_C.RightChild = L_C_R_C



R_C_L_C = TreeNode("Cola")
R_C_R_C = TreeNode("Pepsi")

R_C.LeftChild = R_C_L_C
R_C.RightChild = R_C_R_C

# %%
def Level_Order_Traversal(rootNode):
    if not rootNode:
        return
    else:
        q = Queue()
        q.enqueue(rootNode)
        while not(q.isEmpty()):
            root = q.dequeue()
            print(root.value.data)
            if (root.value.LeftChild is not None):
                q.enqueue(root.value.LeftChild)
                
            if (root.value.RightChild is not None):
                q.enqueue(root.value.RightChild)

# %% [markdown]
# ![30.PNG](attachment:30.PNG)

# %%
Level_Order_Traversal(T)
# Out:
# Drinks
# Hot
# Cold
# Tea
# Coffee
# Cola
# Pepsi

# %%
def Search_in_tree_with_Level_Order_Traversal(rootNode,nodeValue):
    if not rootNode:
        return
    else:
        q = Queue()
        q.enqueue(rootNode)
        while not(q.isEmpty()):
            root = q.dequeue()
            if root.value.data == nodeValue:
                return "Success"
            print(root.value.data)
            if (root.value.LeftChild is not None):
                q.enqueue(root.value.LeftChild)
                
            if (root.value.RightChild is not None):
                q.enqueue(root.value.RightChild)
        
        return "Not Found"

# %%
Search_in_tree_with_Level_Order_Traversal(T,"Tea")
# Out:
# Drinks
# Hot
# Cold
# 'Success'

# %%
Search_in_tree_with_Level_Order_Traversal(T,"Sprite")
# Out:
# Drinks
# Hot
# Cold
# Tea
# Coffee
# Cola
# Pepsi
# 'Not Found'

# %% [markdown]
# # Insert in a Binary Tree
# ![29.PNG](attachment:29.PNG)
#
#
# ### Time Complexity : $O(N)$ , Beacause while Loop
# ### Space Complexity : $O(N)$ , Because Creating Queue and inserting elements

# %%
def insertNodeBT(rootNode , newNode):
    if not rootNode:
        rootNode = newNode
    else:
        q = Queue()
        q.enqueue(rootNode)
        while not(q.isEmpty()):
            root = q.dequeue()
            if (root.value.LeftChild is not None):
                q.enqueue(root.value.LeftChild)
            else:
                root.value.LeftChild = newNode
                return "Successfully Inserted into Tree"
                
            if (root.value.RightChild is not None):
                q.enqueue(root.value.RightChild)
                
            else:
                root.value.LeftChild = newNode
                return "Successfully Inserted into Tree"

# %% [markdown]
# ![32.PNG](attachment:32.PNG)

# %%
newNode = TreeNode("Irani Tea")
insertNodeBT( T , newNode)
# Out:
# 'Successfully Inserted into Tree'

# %%
Level_Order_Traversal(T)
# Out:
# Drinks
# Hot
# Cold
# Tea
# Coffee
# Cola
# Pepsi
# Irani Tea

# %% [markdown]
# # Delete a Node from Binary Tree
# ![33.PNG](attachment:33.PNG)
# > ## Get Deepest Node
#
# > ## Delete Deepest Node
#
# > ## Delete a Node from Binary Tree

# %%
def get_deepest_node(rootNode):
    if not rootNode:
        return
    else:
        q = Queue()
        q.enqueue(rootNode)
        while not(q.isEmpty()):
            root = q.dequeue()
            if (root.value.LeftChild is not None):
                q.enqueue(root.value.LeftChild)
                
            if (root.value.RightChild is not None):
                q.enqueue(root.value.RightChild)
        deepestNode = root.value
        return deepestNode

# %% [markdown]
# ![35.PNG](attachment:35.PNG)

# %%
deepest = get_deepest_node(T)
deepest.data
# Out:
# 'Irani Tea'

# %%
def deleteDeepestNode(rootNode, dNode):
    if not rootNode:
        return
    else:
        q = Queue()
        q.enqueue(rootNode)
        while not(q.isEmpty()):
            root = q.dequeue()
            if root.value is dNode:
                root.value = None
                return
            if root.value.RightChild:
                if root.value.RightChild is dNode:
                    root.value.RightChild = None
                    return
                else:
                    q.enqueue(root.value.RightChild)
            if root.value.LeftChild:
                if root.value.LeftChild is dNode:
                    root.value.LeftChild = None
                    return
                else:
                    q.enqueue(root.value.LeftChild)

# %% [markdown]
# ![34.PNG](attachment:34.PNG)

# %%
DeepestNode = get_deepest_node(T)
deleteDeepestNode(T,DeepestNode)

# %%
Level_Order_Traversal(T)
# Out:
# Drinks
# Hot
# Cold
# Tea
# Coffee
# Cola
# Pepsi

# %%
def Delete_Node(rootNode,DeleteNode , deepest):
    if not rootNode:
        return 
    q = Queue()
    q.enqueue(rootNode)
    while not(q.isEmpty()):
        root = q.dequeue()


        if (root.value.LeftChild is not None):
            if root.value.LeftChild.data == DeleteNode:
                root.value.LeftChild = deepest
                return "Deleted"
            
            else:
                q.enqueue(root.value.LeftChild)


        if (root.value.RightChild is not None):
            if root.value.RightChild.data == DeleteNode:
                root.value.RightChild = deepest
                return "Deleted"
            
            else:
                q.enqueue(root.value.LeftChild)

# %%
Delete_Node(T , "Cold" , deepest)
# Out:
# 'Deleted'

# %%
Level_Order_Traversal(T)
# Out:
# Drinks
# Hot
# Irani Tea
# Tea
# Coffee

# %% [markdown]
# # Delete Entire Tree

# %%
def Delete_BT(rootNode):
    rootNode.data = None
    rootNode.LeftChild = None
    rootNode.RightChild = None
    
    
    return "Tree Deleted"

# %%
Delete_BT(T)
# Out:
# 'Tree Deleted'

# %%
Level_Order_Traversal(T)
# Out:
# None
